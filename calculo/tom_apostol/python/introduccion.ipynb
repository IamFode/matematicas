# %% [markdown]
# <h1>Axiomas de cuerpo</h1>

# %% [markdown]
# <h3>Axioma 1 .- Propiedad conmutativa</h3>

# %%
def axioma1(x,y):
    print('+: ', x, ' + ', y, ' = ', y, ' + ', x, ' = ', x+y)
    print('*: ' , x, ' * ', y, ' = ', y, ' * ', x, ' = ', x*y)

# %%
axioma1(4,5)
# Out:
# +:  4  +  5  =  5  +  4  =  9
# *:  4  *  5  =  5  *  4  =  20

# %% [markdown]
# <h3>Axioma 2.- Propiedad Asociativa</h3>

# %%
x=0
while x>=0:
    x+=1
    print(x)
