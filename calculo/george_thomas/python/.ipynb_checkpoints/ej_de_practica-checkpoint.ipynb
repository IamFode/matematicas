# %% [markdown]
# # Ejercicios de práctica

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math
sns.set()

# %% [markdown]
# ## 1.

# %%
x = np.arange(0,20,0.001)
f = x**(1/5)
plt.plot(x,f)
plt.show()

# %% [markdown]
# # 2.

# %%
x = np.arange(-18,20,0.001)
f = x**2 - 2*x - 1
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 3.

# %%
x = np.arange(-2,2,0.001)
f = math.e**(x**2) 
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 9.

# %%
x = np.arange(-2,2,0.001)
f = x**2 + 1 
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 10.

# %%
x = np.arange(-2,2,0.001)
f = x**5 -x**3 - x 
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 11.

# %%
x = np.arange(-10,10,0.001)
f = 1 - np.cos(x) 
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 14.

# %%
x = np.arange(-10,10,0.001)
f = x - np.sin(x) 
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 15.

# %%
x = np.arange(-10,10,0.001)
f = x + np.cos(x) 
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 16.

# %%
x = np.arange(-15,15,0.001)
f = x * np.cos(x) 
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 17.
#
# ### b.

# %%
x = np.arange(-2,2,0.01)
f = x**3
plt.plot(x,f)
plt.show()

# %% [markdown]
# ### c.

# %%
x = np.arange(-2,2,0.01)
f = np.sin(x)
plt.plot(x,f)
plt.show()

# %% [markdown]
# ### e.

# %%
x = np.arange(-2,2,0.01)
f = abs(x) 
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 29.
#
# ### a)

# %%
x = np.arange(-10,10,0.01)
v = 4/3 * np.pi * x**3
fig, ax = plt.subplots()
ax.plot(x,v)
plt.show()

# %% [markdown]
# ## 30.
#
# ### a)

# %%
x = np.arange(-2,6,0.01)
f = abs(x-2) + 1
fig, ax = plt.subplots()
ax.plot(x,f)
ax.set_xlabel("x")
ax.set_ylabel("f(x)")
ax.set_title("f(x)=$|x-2|+1$")
plt.show()

# %% [markdown]
# ### b)

# %%
x = np.arange(-4,2,0.02)
f = (x+1)**4
fig, ax = plt.subplots()
ax.plot(x,f)
ax.set(xlabel="x", ylabel="f(x)",title="$f(x)=(x+1)^4$")
plt.show()

# %% [markdown]
# ### c)

# %%
x = np.arange(0,10,0.01)
f = (3*x+1)**(1/3)
fig, ax = plt.subplots()
ax.plot(x,f)
ax.set(xlabel="x",ylabel="f(x)",title="$f(x)=(3x-1)^{1/3}$")
plt.show()

# %% [markdown]
# ## 41 al 48

# %%
x = np.arange(-10,10,0.01)
f1, t1 = x, abs(x)
f2, t2 = x**2, abs(x)**2
f3, t3 = x**3, abs(x)**3
f4, t4 = x**2 + x, abs(x**2 + x)
f5, t5 = 4 - x**2, abs(4 - x**2)
f6, t6 = 1/x, 1/abs(x)
f7, t7 = np.sqrt(x), abs(np.sqrt(x)) 
f8, t8 = np.sin(x), np.sin(abs(x))
fig, ax = plt.subplots(2,4,figsize=(20,8))
ax[0,0].plot(f1,t1)
ax[0,0].plot(f2,t2)
ax[0,0].set_title("41")
ax[0,1].plot(x,f2)
ax[0,1].plot(x,t2)
ax[0,1].set_title("42")
ax[0,2].plot(x,f3)
ax[0,2].plot(x,t3)
ax[0,2].set_title("43")
ax[0,3].plot(x,f4)
ax[0,3].plot(x,t4)
ax[0,3].set_title("44")
ax[1,0].plot(x,f5)
ax[1,0].plot(x,t5)
ax[1,0].set_title("45")
ax[1,1].plot(x,f6)
ax[1,1].plot(x,t6)
ax[1,1].set_title("46")
ax[1,2].plot(x,f7)
ax[1,2].plot(x,t7)
ax[1,2].set_title("47")
ax[1,3].plot(x,f8)
ax[1,3].plot(x,t8)
ax[1,3].set_title("48")
plt.show()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in sqrt

# %% [markdown]
# ## 50.

# %%
x = np.arange(-20,20,0.01)
a = (x-5)**2 
b = 4*x**2
c = (-3*x)**2
d = 2*x**2 + 1
e = ((x**2)/3) - 4
f = -3*(x**2) + 1/4
fig, ax = plt.subplots(3,2, figsize = (10,8))
ax[0,0].plot(x,a)
ax[0,1].plot(x,b)
ax[1,0].plot(x,c)
ax[1,1].plot(x,d)
ax[2,0].plot(x,e)
ax[2,1].plot(x,f)
plt.show()

# %% [markdown]
# ## 55.

# %%
x = np.arange(0,2*np.pi,0.01)
f = np.cos(2*x)
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 56.

# %%
x = np.arange(0,4*np.pi,0.01)
f = np.sin(x/2)
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 57.

# %%
x = np.arange(0,2,0.01)
f = np.sin(np.pi*x) 
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 58.

# %%
x = np.arange(0,4,0.01)
f = np.sin((np.pi*x)/2) 
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 59.

# %%
x = np.arange(0,2*np.pi,0.01)
f = 2*np.cos(x - np.pi/3) 
plt.plot(x,f)
plt.show()

# %% [markdown]
# ## 60.

# %%
x = np.arange(0,2*np.pi,0.01)
f = 1 + np.sin(x - np.pi/4) 
plt.plot(x,f)
plt.show()
