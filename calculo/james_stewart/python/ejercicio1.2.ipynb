# %% [markdown]
# # 1.2 Ejercicios

# %%
# importar 
import matplotlib.pyplot as plt 
import numpy as np
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %% [markdown]
# ## 18

# %% [markdown]
# $$C(s)=13s + 900$$

# %%
s = np.arange(0, 300, 0.01)
c = 13*s + 900
fig, ax = plt.subplots()
ax.plot(s, c)
ax.set(xlabel='Sillas producidas', ylabel='Costo en $',
       title='Costo en función de las sillas producidas')
ax.grid()
plt.show()

# %% [markdown]
# ## 19

# %% [markdown]
# $$p(s)=1.05 - 0.10 s$$

# %%
s = np.arange(1.05,60,0.01)
p = 1.05 + 0.1*s

fig, ax = plt.subplots()
ax.plot(s,p)

ax.set(xlabel="Profundidad en cm", ylabel="Presión del agua en $kg/cm^2$", title="Presión del agua en función de la profundidad")
ax.grid()
plt.show()

# %% [markdown]
# ### 20.

# %% [markdown]
# ### a.

# %% [markdown]
# $$C(x)=5.5\cdot d - 1322$$

# %%
C = lambda d : 5.5*d - 1322

# %% [markdown]
# ### b.

# %%
C(2400)
# Out:
# 11878.0

# %% [markdown]
# ### c.

# %% [markdown]
# d = np.arange(200,2400,0.002)
# C = 5.5*d - 1322
# fig,ax = plt.subplots()
# ax.plot(d,C)
# ax.set(xlabel="Distancia", ylabel = "Costo", title="Costo de conducir un auto")
# ax.grid()
# plt.show()

# %% [markdown]
# ### d.

# %%
C(0)
# Out:
# -1322.0

# %% [markdown]
# ## 21.

# %% [markdown]
# ### (a)

# %%
x = np.arange(0,20,0.02)
f = np.cos(x) + 10
conf,ax = plt.subplots()
ax.plot(x,f)
ax.set(xlabel="x", ylabel="f(x)", title="función coseno")
ax.grid()
plt.show()

# %%
x = np.arange(0,100,00.2)
f = -1*x + 3
conf, ax = plt.subplots()
ax.plot(x,f)
ax.set(xlabel="x",ylabel="f(x)",title="Función lineal")
ax.grid()
plt.show()

# %% [markdown]
# ## 22.

# %% [markdown]
# ### (a)

# %%
x = np.arange(0,3,00.2)
f = 4**x + 10
conf,ax = plt.subplots()
ax.plot(x,f)
ax.set(xlabel="x",ylabel="f(x)",title="Función exponencial")
ax.grid
plt.show()

# %% [markdown]
# ### (b)

# %%
x = np.arange(0,3,00.2)
f = 1/4**x + 10
f = 1/4**x + 10
conf,ax = plt.subplots()
ax.plot(x,f)
ax.set(xlabel="x",ylabel="f(x)",title="Función exponencial")
ax.grid
plt.show()

# %% [markdown]
# ## 23.

# %% [markdown]
# ### (a)

# %%
i = [4000,6000,8000,12000,16000,20000,30000,45000,60000]
t = [14.1,13.0,13.4,12.5,12.0,12.4,10.5,9.4,8.2]

# %%
conf,ax = plt.subplots()
ax.scatter(i,t)
ax.set(xlabel="Ingreso",ylabel="Tasa de úlcera",title="Tasa de úlcera péptica en función del ingreso familiar")
ax.grid
plt.show()

# %% [markdown]
# ### (b)
# $$T = -\dfrac{5.9}{56000}I + \dfrac{2033}{140}$$

# %%
m = (t[-1]-t[0])/(i[-1]-i[0])
b = t[0] + m*i[0]
m
# Out:
# -0.00010535714285714286

# %%
def T(I):
    return m*I + b

# %% [markdown]
# ### (c)
#
# $$T=-9.979\cdot 10^{-5} I + 13.9508$$

# %%
def T(i):
    return -9.979*10**(-5)*i + 13.9508

# %%
x = sm.add_constant(i)
results = sm.OLS(t,x).fit()
results.summary()
# Out:
# c:\users\fode\appdata\local\programs\python\python38\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     180.2
# Date:                Sun, 09 May 2021   Prob (F-statistic):           2.99e-06
# Time:                        14:45:01   Log-Likelihood:                -3.4808
# No. Observations:                   9   AIC:                             10.96
# Df Residuals:                       7   BIC:                             11.36
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ## (d)

# %%
T(25000)
# Out:
# 11.45605

# %% [markdown]
# ### (e)

# %%
T(80000)
# Out:
# 5.967599999999999

# %% [markdown]
# ### (f)

# %%
T(200000)
# Out:
# -6.007200000000003

# %% [markdown]
# ## 24.

# %%
t = [20,22,24,26,28,30,32,34,36]
c = [113,128,143,158,173,188,203,218,233]

# %%
#(a)
conf,ax = plt.subplots()
ax.scatter(t,c)
ax.set(xlabel = "Temperatura ($^\circ C$)", ylabel = "Tasa de chirridos (chirridos/min)",title = "Chirrido de grillos")
plt.show()

# %%
#(b)
x = sm.add_constant(t)
results = sm.OLS(c,x).fit()
results.summary()
# Out:
# c:\users\fode\appdata\local\programs\python\python38\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 6.609e+29
# Date:                Tue, 11 May 2021   Prob (F-statistic):          1.13e-102
# Time:                        16:02:02   Log-Likelihood:                 254.55
# No. Observations:                   9   AIC:                            -505.1
# Df Residuals:                       7   BIC:                            -504.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
# función 
def c(t):
    return 7.5*t - 37

# %%
# c
c(40)
# Out:
# 263.0

# %% [markdown]
# ### 25

# %%
f = [50.1,48.3,45.2,44.7,44.5,42.7,39.5,38.0]
a = [178.5,173.6,164.8,163.7,168.3,165.0,155.4,155.8]

# %%
fig,ax = plt.subplots()
ax.scatter(f,a)
ax.set(xlabel="Longitud (cm)",ylabel="Altura (cm)",title="Relación entre la longitud del fémur humano y la altura")
ax.plot()
# Out:
# []

# %%
x = sm.add_constant(f)
results = sm.OLS(a,x).fit()
results.summary()
# Out:
# /home/fode/.local/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=8
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.925
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                     74.08
# Date:                Wed, 26 May 2021   Prob (F-statistic):           0.000135
# Time:                        12:08:40   Log-Likelihood:                -17.037
# No. Observations:                   8   AIC:                             38.07
# Df Residuals:                       6   BIC:                             38.23
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
